# %%
from seeq import spy
from seeq.addons import correlation

# %%
# GET /configuration
correlation.python_plotter_configuration()

# %%
# POST /plot
body = REQUEST.get("body") or {}
correlation.python_plotter_plot(body, spy)
